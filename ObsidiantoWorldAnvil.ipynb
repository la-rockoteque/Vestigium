# %% [markdown]
# 1  Setup & helpers

# %%
# %% [markdown]
# Cell 1 – imports & shared helpers
# --------------------------------
from pathlib import Path
import zipfile, os, re, html
from lxml import etree
from tqdm.auto import tqdm
import textile, dotenv
import nest_asyncio, asyncio
nest_asyncio.apply()   # allow nested event loops so Playwright Sync works in notebooks

from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PWTimeout

dotenv.load_dotenv()
WA_EMAIL    = os.environ["WA_EMAIL"]
WA_PASSWORD = os.environ["WA_PASSWORD"]
WA_WORLD    = os.environ["WA_WORLD"]

# %% [markdown]
# 2  Extract your Obsidian Portal backup

# %%
# %% Cell 2 – choose the backup
OP_BACKUP = Path("extracted/rocko_2025-05-05.zip")        # change me
WORK_DIR  = Path("extracted/op")
WORK_DIR.mkdir(exist_ok=True)

with zipfile.ZipFile(OP_BACKUP) as zf:
  zf.extractall(WORK_DIR)

# locate the XML (there’s only one)
try:
    # search recursively in case the XML is nested inside a sub‑folder
    export_xml = next(WORK_DIR.rglob("*.xml"))
except StopIteration:
    raise FileNotFoundError(
        "No .xml file found in the extracted backup. "
        "Double‑check OP_BACKUP or inspect WORK_DIR to confirm the archive structure."
    )
print(f"Using OP export file: {export_xml}")
tree       = etree.parse(str(export_xml))
root       = tree.getroot()

# %% [markdown]
# Structure discovery (run once to inspect)

# %%
# %% Cell 3 – peek at tag names
from collections import Counter

tags = Counter([el.tag for el in root.iter()])
tags

# %% [markdown]
# 3  Parse into plain Python dicts

# %%
# %% Cell 4 – generic helpers (Element → dict)
def get(el, tag):
  n = el.find(tag)
  return (n.text or "").strip() if n is not None else ""

def record(el, wanted):
  return {k: get(el, k) for k in wanted}

characters = [
  record(c, ["name", "tagline", "description", "game_statblock"])
  for c in root.findall(".//character")
]

items = [
  record(i, ["name", "description", "tagline"])
  for i in root.findall(".//item")
]

wikis = [
  record(w, ["title", "body", "slug"])
  for w in root.findall(".//wiki_page")
]

logs = [
  record(l, ["title", "body", "post_date"])
  for l in root.findall(".//adventure_log_post")
]

# %% [markdown]
# 4 Convert Textile ‑→ Markdown for World Anvil

# %%
from bs4 import NavigableString, Tag

def html_to_bbcode(html_frag: str) -> str:
  soup = BeautifulSoup(html_frag, "html.parser")

  def walk(node):
    if isinstance(node, NavigableString):
      return str(node)

    if not isinstance(node, Tag):
      return ""

    name   = node.name.lower()
    inside = "".join(walk(c) for c in node.children)

    # basic mapping for common tags
    tag_map = {
      ("strong", "b"):        ("[b]",   "[/b]"),
      ("em", "i"):            ("[i]",   "[/i]"),
      ("u",):                 ("[u]",   "[/u]"),
      ("strike", "del", "s"): ("[s]",   "[/s]"),
      ("code",):              ("[code]","[/code]"),
      ("blockquote",):        ("[quote]","[/quote]"),
    }
    for keys, (open_, close_) in tag_map.items():
      if name in keys:
        return f"{open_}{inside}{close_}"

    if name == "br":
      return "\n"
    if name == "p":
      return f"{inside}\n\n"
    if name in ("h1","h2","h3","h4","h5","h6"):
      level = name[1]
      return f"[h{level}]{inside}[/h{level}]\n"
    if name == "a":
      href = node.get("href","")
      return f"[url={href}]{inside}[/url]"
    if name == "img":
      src = node.get("src","")
      return f"[img]{src}[/img]"
    if name == "ul":
      return f"[ul]{inside}[/ul]\n"
    if name == "ol":
      return f"[ol]{inside}[/ol]\n"
    if name == "li":
      return f"[*]{inside}[/*]"

    return inside

def textile_to_bbcode(text):
  """
  Convert a Textile fragment to BBCode (World Anvil’s preferred markup).
  1. Textile → HTML        via `textile`
  2. HTML    → BBCode      via `html2bbcode`
  """
  html_frag = textile.textile(text or "")
  return html_to_bbcode(html_frag)

for col in ("description", "body", "game_statblock"):
  for bank in (characters, items, wikis, logs):
    for rec in bank:
      if col in rec:
        rec[col] = textile_to_bbcode(rec[col])

# %% [markdown]
# 5 Headless upload via Playwright
#
# Selector stability: WA rolls out UI tweaks frequently.
# Inspect your own “Create Article” form (worldanvil.com/w/{WA_WORLD}/editor/new) with DevTools and adjust the CSS/XPath selectors below if they drift.

# %%
# %% Cell 6 – playwright session wrapper
class WA:
  async def __aenter__(self):
    self.pw = await async_playwright().start()
    # persistent context lets us stay logged‑in between actions
    self.ctx = await self.pw.chromium.launch_persistent_context(
      user_data_dir="pw_profile",
      headless=False          # flip to True once everything is stable
    )
    self.page = await self.ctx.new_page()
    self.page.on("console", lambda m: print("PAGE LOG:", m.text))
    self.page.on("requestfailed", lambda r: print("REQ FAIL:", r.url, r.failure))
    return self

  async def __aexit__(self, exc_type, exc, tb):
    await self.ctx.close()
    await self.pw.stop()

  # ---------- actions ----------
  async def login(self):
    # Navigate to login and wait for the DOM to be ready
    await self.page.goto("https://www.worldanvil.com/login", wait_until="domcontentloaded")

    # Wait until the username field is actually present & visible (handles Cloudflare / slow net)
    # await self.page.wait_for_selector("input#username", state="visible", timeout=30000)
    # await self.page.fill('input#username', WA_EMAIL)     # <input id="username" name="_username">
    # await self.page.fill('input#password', WA_PASSWORD)  # <input id="password" name="_password">
    # 
    # # Submit the form
    # await self.page.click('input#_submit')

  # Make sure every article gets a ≥3‑character title
  def safe_title(raw: str | None, fallback_prefix: str = "Untitled") -> str:
    if raw and len(raw.strip()) >= 3:
      return raw.strip()
    # fallback: generate a unique placeholder
    safe_title.counter += 1
    return f"{fallback_prefix} {safe_title.counter}"
    safe_title.counter = 0
    
  async def new_article(self, *, template="generic", title="", content="", summary=""):
    """
    Use the dashboard’s green **Create a new Article** button, then pick a template
    from the modal. This is the only reliable path as of May‑2025.

    Supported template keys:
      generic, character, item
    """
    # 1.  Land on the world Summary page (the button lives here)
    await self.page.goto(f"https://www.worldanvil.com/world/{WA_WORLD}/summary", wait_until="domcontentloaded")

    # 2.  Wait for the green button and ensure it’s in view, then click
    button = self.page.locator("a.article-quick-create-trigger").first
    await button.wait_for(state="visible", timeout=15000)
    await button.scroll_into_view_if_needed()
    await button.click()

    # 3.  Wait for the modal container to appear
    await self.page.wait_for_selector("section.chakra-modal__content", timeout=10000)
    # If the modal didn’t appear, abort early with a helpful error
    if not await self.page.locator("section.chakra-modal__content").is_visible():
        raise RuntimeError("Template‑picker modal did not open; the Create button may have failed.")

    # 4.  Pick the correct template card inside the modal
    card_selector_map = {
      "generic":   ".athena-template-generic-template-card",
      "character": ".athena-template-character-template-card",
      "item":      ".athena-template-item-template-card",
    }
    card_sel = card_selector_map.get(template, ".athena-template-generic-template-card")
    await self.page.click(card_sel)

    # 5.  The template card opens the editor in a *new* tab; switch context
    editor_page = self.page.context.pages[-1]   # last opened tab
    await editor_page.wait_for_load_state()

    # 6.  Fill in the editor fields
    title_input = editor_page.locator('input[placeholder="Title"]').first
    await title_input.fill(title[:255])

    frame = editor_page.frame_locator('iframe[id$="description_ifr"]')
    await frame.locator("body").fill(content)

    try:
      await editor_page.fill("textarea#article_excerpt", summary[:511])
    except PWTimeout:
      pass

    # 7.  Save (button text is “Create”)
    await editor_page.click('button:has-text("Create")')
    await editor_page.wait_for_timeout(2000)

    # 8.  Close the tab and return focus to the main dashboard page
    await editor_page.close()

  # Add similar helpers for characters/items if you want specialised templates

# %% [markdown]
# 6 Batch‑create content

# %%
from tqdm.asyncio import tqdm_asyncio  # async progress bar
async def main():
  async with WA() as wa:
    await wa.login()

    for w in tqdm_asyncio(wikis, desc="Wikis"):
      await wa.new_article(
        template="generic",
        title=w["title"],
        content=w["body"],
        summary=w["body"][:200]
      )

    for c in tqdm_asyncio(characters, desc="Characters"):
      await wa.new_article(
        template="character",
        title=c["name"],
        content=(c.get("description") or "") + ("\n\n" if c.get("game_statblock") else "") + (c.get("game_statblock") or ""),
        summary=c["tagline"]
      )

    for it in tqdm_asyncio(items, desc="Items"):
      await wa.new_article(
        template="item",
        title=it["name"],
        content=it["description"],
        summary=it["tagline"]
      )

    for log in tqdm_asyncio(logs, desc="Adventure Logs"):
      await wa.new_article(
        template="generic",
        title=log["title"],
        content=log["body"],
        summary=log["post_date"]
      )

await main()  # Jupyter supports top‑level await
# Out:
# REQ FAIL: https://www.google.com/ccm/collect?tid=AW-825669689&en=page_view&dl=https%3A%2F%2Fwww.worldanvil.com%2Flogin&scrsrc=www.googletagmanager.com&frm=0&rnd=711725009.1746445358&dt=Login%20%7C%20Welcome%20to%20World%20Anvil%20%7C%20World%20Anvil&auid=2021977298.1746443149&navt=n&npa=0&gtm=45be54u1v9121218595za200&gcd=13l3l3l3l1l1&dma=0&tag_exp=101509157~103101750~103101752~103116026~103130495~103130497~103200004~103233427~103251618~103251620&tft=1746445357650&tfd=550&apve=1&apvf=f net::ERR_ABORTED
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777z8857243476za200zb857243476&_p=1746445357636&_gaz=1&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&ec_mode=a&_eu=AAAAAAQ&_s=1&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Flogin&dt=Login%20%7C%20Welcome%20to%20World%20Anvil%20%7C%20World%20Anvil&_tu=QA&en=page_view&tfd=779 net::ERR_ABORTED
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777za200zb857243476&_p=1746445357636&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AEAAAAQ&_s=2&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Flogin&dt=Login%20%7C%20Welcome%20to%20World%20Anvil%20%7C%20World%20Anvil&_tu=QA&en=scroll&epn.percent_scrolled=90&_et=4&tfd=1291 net::ERR_ABORTED
# PAGE LOG: Live Variables
# PAGE LOG: {search: /heroes/live/search/full, templates: /heroes/templates/, diceLog: /heroes/live/dicelog, diceReloader: /heroes/live/dicelog/log, library: /heroes/live/library}
# PAGE LOG: binding mentions
# PAGE LOG: notication module loaded
# PAGE LOG: boards JS loading
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777z8857243476za200zb857243476&_p=1746445358394&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&ec_mode=a&_eu=AAAAAAQ&_s=1&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&dr=https%3A%2F%2Fwww.worldanvil.com%2Flogin&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&_tu=QA&en=page_view&tfd=596 net::ERR_ABORTED
# PAGE LOG: undefined
# PAGE LOG: undefined
# PAGE LOG: Editor injection ========================================================
# PAGE LOG: Currently used Editor: Euclid (CodeMirror)
# PAGE LOG: EOF Editor injection ====================================================
# PAGE LOG: i18next::backendConnector: loaded namespace athena for language en-US {ArticleIllustrativeCreate: Object, AthenaModal: Object, imageActions: Object, layoutSections: Object, modals: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace artemis for language en-US {searchPlaceholder: Search Everything, commands: Object, sortBy: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace erebus for language en-US {hello: world, components: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace bbcode for language en-US {spoiler: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(7), defaultNS: common, fallbackLng: Array(1)}
# Wikis: 0it [00:00, ?it/s]
# Characters:   0%|          | 0/247 [00:00<?, ?it/s]
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: binding Diceroller
# PAGE LOG: trackable events bound
# PAGE LOG: finished loading Javascript.
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: explorer detected
# PAGE LOG: initiating explorer
# PAGE LOG: binding mention system
# PAGE LOG: The Mention class is being loaded on Code
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: i18next::backendConnector: loaded namespace erebus for language en-US {hello: world, components: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next::backendConnector: loaded namespace bbcode for language en-US {spoiler: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace artemis for language en-US {searchPlaceholder: Search Everything, commands: Object, sortBy: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace athena for language en-US {ArticleIllustrativeCreate: Object, AthenaModal: Object, imageActions: Object, layoutSections: Object, modals: Object}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(7), defaultNS: common, fallbackLng: Array(1)}
# PAGE LOG: isApolloOpen false
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(1), defaultNS: common, fallbackLng: Array(1)}
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/seasonalOfferBanner-C2sCh0g2.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/ClaimBadgeModal-C53v15Ox.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/studioModal-CQVVrnBe.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/searchBar-COHxTIsG.js net::ERR_ABORTED
# PAGE LOG: Hello, Gogluness!
# PAGE LOG: User SystemMeta:  {announcement375: dismissed, announcement434: dismissed, announcement601: dismissed, announcement317: dismissed, announcement602: dismissed}
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/CoursesModal-DQPaqGUl.js net::ERR_ABORTED
# PAGE LOG: older than 10 days: pass
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/athenaModal-CPiiuIo9.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/membershipAdvertModal-B03MX1Ko.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# PAGE LOG: No active campaign found! Checking for default campaign
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/confirmDeleteModal-CrIV01PP.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/GenericTabPanel-J0bmvaDs.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/NewsAndCommunityModal-DRjwFk25.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/lato-latin-400-normal-BEhtfm5r.woff2 net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/ApolloWrapper-CRcGMh3z.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/upgradeModal-DZ5T22AE.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/notificationsModal-CdOirmrn.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/swiper-react-CP48_ojG.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/activateEntityModal-BgmZJHut.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/discoverModal-QZ29Behh.js net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/api/internal/aboleth/world/campaigns?id=e37c71d1-a1ae-450a-ab53-8d25ef2a245f net::ERR_ABORTED
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777za200zb857243476&_p=1746445358394&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AEAAAAQ&_s=2&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&dr=https%3A%2F%2Fwww.worldanvil.com%2Flogin&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&_tu=QA&en=scroll&epn.percent_scrolled=90&_et=5&tfd=1646 net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/assets/helpCenter-CTZlcQaK.js net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/assets/PrimaryUseTypeModal-B8CnroTJ.js net::ERR_ABORTED
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777za200zb857243476&_p=1746445358394&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AAAAAAQ&_s=3&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&dr=https%3A%2F%2Fwww.worldanvil.com%2Flogin&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&_tu=QA&en=user_engagement&_et=1041&tfd=1647 net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/cdn-cgi/rum? net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/assets/welcomeModal-Drk4bSdD.js net::ERR_ABORTED
# REQ FAIL: https://www.worldanvil.com/assets/lato-latin-400-normal-B11PyLys.woff net::ERR_ABORTED
# PAGE LOG: Live Variables
# PAGE LOG: {search: /heroes/live/search/full, templates: /heroes/templates/, diceLog: /heroes/live/dicelog, diceReloader: /heroes/live/dicelog/log, library: /heroes/live/library}
# PAGE LOG: binding mentions
# PAGE LOG: notication module loaded
# PAGE LOG: boards JS loading
# REQ FAIL: https://googleads.g.doubleclick.net/pagead/id net::ERR_ABORTED
# PAGE LOG: undefined
# PAGE LOG: undefined
# PAGE LOG: Editor injection ========================================================
# PAGE LOG: Currently used Editor: Euclid (CodeMirror)
# PAGE LOG: EOF Editor injection ====================================================
# REQ FAIL: https://www.google.com/ccm/collect?tid=AW-825669689&en=page_view&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&scrsrc=www.googletagmanager.com&frm=0&rnd=425836793.1746445360&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&auid=2021977298.1746443149&navt=n&npa=0&gtm=45be54u1v9121218595za200&gcd=13l3l3l3l1l1&dma=0&tag_exp=101509157~103101750~103101752~103116026~103130495~103130497~103200004~103233427~103251618~103251620&tft=1746445359501&tfd=424&apve=1&apvf=f net::ERR_ABORTED
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next::backendConnector: loaded namespace erebus for language en-US {hello: world, components: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace athena for language en-US {ArticleIllustrativeCreate: Object, AthenaModal: Object, imageActions: Object, layoutSections: Object, modals: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace artemis for language en-US {searchPlaceholder: Search Everything, commands: Object, sortBy: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace bbcode for language en-US {spoiler: Object}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(7), defaultNS: common, fallbackLng: Array(1)}
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777z8857243476za200zb857243476&_p=1746445359479&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&ec_mode=a&_eu=AAAAAAQ&_s=1&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&_tu=QA&en=page_view&tfd=453 net::ERR_ABORTED
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: binding Diceroller
# PAGE LOG: trackable events bound
# PAGE LOG: finished loading Javascript.
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: delay: initialised
# PAGE LOG: explorer detected
# PAGE LOG: initiating explorer
# PAGE LOG: binding mention system
# PAGE LOG: The Mention class is being loaded on Code
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: Tooltipster: one or more tooltips are already attached to the element below. Ignoring.
# PAGE LOG: JSHandle@node
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: isApolloOpen false
# PAGE LOG: i18next::backendConnector: loaded namespace artemis for language en-US {searchPlaceholder: Search Everything, commands: Object, sortBy: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace erebus for language en-US {hello: world, components: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next::backendConnector: loaded namespace bbcode for language en-US {spoiler: Object}
# PAGE LOG: i18next::backendConnector: loaded namespace athena for language en-US {ArticleIllustrativeCreate: Object, AthenaModal: Object, imageActions: Object, layoutSections: Object, modals: Object}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(7), defaultNS: common, fallbackLng: Array(1)}
# PAGE LOG: i18next::backendConnector: loaded namespace common for language en-US {privacy: Object, publishedState: Object, comments: Object, likes_one: Like, likes_other: Likes}
# PAGE LOG: i18next: languageChanged en-US
# PAGE LOG: i18next: initialized {debug: true, initImmediate: true, ns: Array(1), defaultNS: common, fallbackLng: Array(1)}
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/notificationsModal-CdOirmrn.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/swiper-react-CP48_ojG.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/upgradeModal-DZ5T22AE.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/PrimaryUseTypeModal-B8CnroTJ.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/discoverModal-QZ29Behh.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/studioModal-CQVVrnBe.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/ClaimBadgeModal-C53v15Ox.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/searchBar-COHxTIsG.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/activateEntityModal-BgmZJHut.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/helpCenter-CTZlcQaK.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/GenericTabPanel-J0bmvaDs.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/ApolloWrapper-CRcGMh3z.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/confirmDeleteModal-CrIV01PP.js net::ERR_ABORTED
# PAGE LOG: Hello, Gogluness!
# PAGE LOG: User SystemMeta:  {announcement375: dismissed, announcement434: dismissed, announcement601: dismissed, announcement317: dismissed, announcement602: dismissed}
# PAGE LOG: older than 10 days: pass
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/CoursesModal-DQPaqGUl.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/welcomeModal-Drk4bSdD.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/lato-latin-400-normal-BEhtfm5r.woff2 net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/membershipAdvertModal-B03MX1Ko.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/athenaModal-CPiiuIo9.js net::ERR_ABORTED
# PAGE LOG: No active campaign found! Checking for default campaign
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/NewsAndCommunityModal-DRjwFk25.js net::ERR_ABORTED
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/seasonalOfferBanner-C2sCh0g2.js net::ERR_ABORTED
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] No metadata available, skipping world index load
# PAGE LOG: Failed to load resource: the server responded with a status of 404 ()
# REQ FAIL: https://www.worldanvil.com/assets/lato-latin-400-normal-B11PyLys.woff net::ERR_ABORTED
# PAGE LOG: entityclass without if clause
# PAGE LOG: [PRODROMOS] Loading from API due to missing or stale data
# PAGE LOG: [PRODROMOS] Fetching World Index from API
# PAGE LOG: getWorldIndex called World {id: e37c71d1-a1ae-450a-ab53-8d25ef2a245f, title: Mycée, slug: mycee-gogluness, campaignId: null, campaignTitle: null}
# PAGE LOG: getWorldIndex response {articles: Object, manuscripts: Array(0), lastIndexConsolidation: 1738503985}
# PAGE LOG: [PRODROMOS] Upserting 104 articles into local database
# PAGE LOG: [PRODROMOS] Successfully upserted articles into database
# PAGE LOG: Quick Create Article (Worldbuilder)
# PAGE LOG: Quick Create Article (Worldbuilder)
# PAGE LOG: custom template entity:  {title: Character, icon: fa-person, url: https://www.worldanvil.com/world/person/new, type: person, synonyms: deity character god npc pc}
# PAGE LOG: draftPermission {enabled: true, limit: -1, limitedBy: user}
# PAGE LOG: world {id: e37c71d1-a1ae-450a-ab53-8d25ef2a245f, title: Mycée, slug: mycee-gogluness, state: public, isWip: null}
# PAGE LOG: Trigger icon:  undefined
# PAGE LOG: [EUCLID] Setting up extensions
# PAGE LOG: [EUCLID] Initializing mentions plugin
# PAGE LOG: [EUCLID] Setting up extensions
# PAGE LOG: [EUCLID] Initializing mentions plugin
# PAGE LOG: canRemove true undefined
# PAGE LOG: [EUCLID] Setting up extensions
# PAGE LOG: [EUCLID] Initializing mentions plugin
# PAGE LOG: Trigger icon:
# PAGE LOG: Trigger icon:  undefined
# PAGE LOG: [Athena] Person article form validation failed {formErrors: Array(0), fieldErrors: Object} {editor: code, title: , content: , state: public, isDraft: true}
# REQ FAIL: https://analytics.google.com/g/collect?v=2&tid=G-ZW5R4SHNYY&gtm=45je54u1v888737777za200zb857243476&_p=1746445359479&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=101509157~103101750~103101752~103116025~103200001~103211513~103233427~103251618~103251620&ptag_exp=101509156~103101747~103101749~103116026~103200004~103233424~103251618~103251620&cid=1010083131.1746443149&ecid=2079364196&ul=en-us&sr=1280x720&uaa=arm&uab=64&uafvl=Not.A%252FBrand%3B99.0.0.0%7CChromium%3B136.0.7103.25&uamb=0&uam=&uap=macOS&uapv=15.3.2&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AEAAAAQ&_s=2&sid=1746443149&sct=1&seg=1&dl=https%3A%2F%2Fwww.worldanvil.com%2Fworld%2Fe37c71d1-a1ae-450a-ab53-8d25ef2a245f%2Fsummary&dt=Myc%C3%A9e%20Dashboard%20%7C%20World%20Anvil&_tu=QA&en=scroll&epn.percent_scrolled=90&_et=16&tfd=5472 net::ERR_ABORTED
# Characters:   0%|          | 0/247 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[59], line 38
#      30     for log in tqdm_asyncio(logs, desc="Adventure Logs"):
#      31       await wa.new_article(
#      32         template="generic",
#      33         title=log["title"],
#      34         content=log["body"],
#      35         summary=log["post_date"]
#      36       )
# ---> 38 await main()  # Jupyter supports top‑level await
#
# Cell In[59], line 3, in main()
#       2 async def main():
# ----> 3   async with WA() as wa:
#       4     await wa.login()
#       6     for w in tqdm_asyncio(wikis, desc="Wikis"):
#
# Cell In[54], line 16, in WA.__aexit__(self, exc_type, exc, tb)
#      15 async def __aexit__(self, exc_type, exc, tb):
# ---> 16   await self.ctx.close()
#      17   await self.pw.stop()
#
# File ~/dev/VestigiumFoundrySpells/.venv/lib/python3.13/site-packages/playwright/async_api/_generated.py:13448, in BrowserContext.close(self, reason)
#   13435 async def close(self, *, reason: typing.Optional[str] = None) -> None:
#   13436     """BrowserContext.close
#   13437
#   13438     Closes the browser context. All the pages that belong to the browser context will be closed.
#    (...)  13445         The reason to be reported to the operations interrupted by the context closure.
#   13446     """
# > 13448     return mapping.from_maybe_impl(await self._impl_obj.close(reason=reason))
#
# File ~/dev/VestigiumFoundrySpells/.venv/lib/python3.13/site-packages/playwright/_impl/_browser_context.py:599, in BrowserContext.close(self, reason)
#     596         await har.delete()
#     598 await self._channel._connection.wrap_api_call(_inner_close, True)
# --> 599 await self._channel.send("close", {"reason": reason})
#     600 await self._closed_future
#
# File ~/dev/VestigiumFoundrySpells/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/dev/VestigiumFoundrySpells/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserContext.close: Target page, context or browser has been closed
